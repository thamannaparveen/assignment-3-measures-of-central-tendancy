# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\thama\Downloads\StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 5    female        group B                 high school  free/reduced
# 6    female        group B            some high school  free/reduced
# 7    female        group D          associate's degree  free/reduced
# 8    female        group D            some high school  free/reduced
# 9    female        group C                 high school      standard
# 10   female        group C            some high school  free/reduced
# 11   female        group D           bachelor's degree  free/reduced
# 12   female        group B            some high school      standard
# ...

# %%
pd.value_counts(data['gender'])
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
pd.value_counts(data['parental level of education'])
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
gr=data.groupby('gender')
f=(gr.get_group('female'))
f
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 5    female        group B                 high school  free/reduced
# 6    female        group B            some high school  free/reduced
# 7    female        group D          associate's degree  free/reduced
# 8    female        group D            some high school  free/reduced
# 9    female        group C                 high school      standard
# 10   female        group C            some high school  free/reduced
# 11   female        group D           bachelor's degree  free/reduced
# 12   female        group B            some high school      standard
# ...

# %%
m=(gr.get_group('male'))
m
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 518   male        group C                 high school  free/reduced
# 519   male        group A                some college  free/reduced
# 520   male        group B                 high school  free/reduced
# 521   male        group E            some high school      standard
# 522   male        group B                some college  free/reduced
# 523   male        group B                some college  free/reduced
# 524   male        group C                some college  free/reduced
# 525   male        group D                 high school  free/reduced
# 526   male        group B                 high school  free/reduced
# 527   male        group C           bachelor's degree  free/reduced
# 528   male        group B            some high school  free/reduced
# 529   male        group A            some high school  free/reduced
# 530   male        group D           bachelor's degree  free/reduced
# ...

# %%
print('Average score in Maths for female students is',f['math score'].mean())
print('Average score in Maths for male students is',m['math score'].mean())
# Out:
# Average score in Maths for female students is 63.37644787644788
# Average score in Maths for male students is 68.82157676348548

# %%
print('Average score in Reading for female students is',f['reading score'].mean())
print('Average score in Reading for male students is',m['reading score'].mean())
# Out:
# Average score in Reading for female students is 72.59073359073359
# Average score in Reading for male students is 65.54564315352697

# %%
print('Average score in Writing for female students is',f['writing score'].mean())
print('Average score in Writing for male students is',m['writing score'].mean())
# Out:
# Average score in Writing for female students is 72.46718146718146
# Average score in Writing for male students is 63.446058091286304

# %%
gr1 = data.groupby('test preparation course')

# %%
n=(gr1.get_group('none'))
n
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# 6    female        group B            some high school  free/reduced
# 7    female        group D          associate's degree  free/reduced
# 8    female        group D            some high school  free/reduced
# 9    female        group C                 high school      standard
# 11   female        group D           bachelor's degree  free/reduced
# 13   female        group C                some college  free/reduced
# 14   female        group E            some high school  free/reduced
# 15   female        group C                 high school  free/reduced
# ...

# %%
c=(gr1.get_group('completed'))
c
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 5    female        group B                 high school  free/reduced
# 10   female        group C            some high school  free/reduced
# 12   female        group B            some high school      standard
# 16   female        group A                 high school  free/reduced
# 21   female        group D            some high school  free/reduced
# 35   female        group D            some high school  free/reduced
# 42   female        group C                some college  free/reduced
# 43   female        group D          associate's degree  free/reduced
# 44   female        group E                some college  free/reduced
# 45   female        group C           bachelor's degree  free/reduced
# 53   female        group C            some high school      standard
# 57   female        group C                some college  free/reduced
# 60   female        group B                 high school  free/reduced
# ...

# %%
print('Average score in Maths for students who not taken test preparation course is',n['math score'].mean())
print('Average score in Maths for students who completed test preparation course is',c['math score'].mean())
# Out:
# Average score in Maths for students who not taken test preparation course is 63.78971962616822
# Average score in Maths for students who completed test preparation course is 69.96648044692738

# %%
print('Average score in Reading for students who not taken test preparation course is',n['reading score'].mean())
print('Average score in Reading for students who completed test preparation course is',c['reading score'].mean())
# Out:
# Average score in Reading for students who not taken test preparation course is 66.41744548286604
# Average score in Reading for students who completed test preparation course is 74.17597765363128

# %%
print('Average score in Writing for students who not taken test preparation course is',n['writing score'].mean())
print('Average score in Writing for students who completed test preparation course is',c['writing score'].mean())
# Out:
# Average score in Writing for students who not taken test preparation course is 64.45794392523365
# Average score in Writing for students who completed test preparation course is 74.68435754189944

# %%
f['math score'].std()
# Out:
# 16.029928046024416

# %%
m['math score'].std()
# Out:
# 14.556410851750082

# %%
f['reading score'].std()
# Out:
# 14.411017942724348

# %%
m['reading score'].std()
# Out:
# 14.149593990092217

# %%
f['writing score'].std()
# Out:
# 14.844841765750752

# %%
m['writing score'].std()
# Out:
# 14.227224751791567

# %%
print('Standard deviation of Maths score of students who are not taken the test preparation course is =',n['math score'].std())
# Out:
# Standard deviation of Maths score of students who are not taken the test preparation course is = 15.705688832386162

# %%
print('Standard deviation of Maths score of students who completed the test preparation course is =',c['math score'].std())
# Out:
# Standard deviation of Maths score of students who completed the test preparation course is = 14.521846554552155

# %%
print('Standard deviation of Reading score of students who are not taken the test preparation course is =',n['reading score'].std())
# Out:
# Standard deviation of Reading score of students who are not taken the test preparation course is = 14.608896302820787

# %%
print('Standard deviation of Reading score of students who are completed the test preparation course is =',c['reading score'].std())
# Out:
# Standard deviation of Reading score of students who are completed the test preparation course is = 13.537572304052691

# %%
print('Standard deviation of Writing score of students who are not taken the test preparation course is =',n['writing score'].std())
# Out:
# Standard deviation of Writing score of students who are not taken the test preparation course is = 15.041666751649458

# %%
print('Standard deviation of Writing score of students who are completed the test preparation course is =',c['writing score'].std())
# Out:
# Standard deviation of Writing score of students who are completed the test preparation course is = 13.236412345154768

# %%
data.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
Q1=(1000+1)/4
Q1  
#greater than 25% is the first quartile
# Out:
# 250.25

# %%
data.nlargest(250,['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 995    male        group E                some college      standard
# 512  female        group D                some college      standard
# 993    male        group C                some college      standard
# 994    male        group C          associate's degree      standard
# ...
